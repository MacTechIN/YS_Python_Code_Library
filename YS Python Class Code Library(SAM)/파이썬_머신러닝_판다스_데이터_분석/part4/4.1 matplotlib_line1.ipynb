# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Excel 데이터를 데이터프레임 변환 
df = pd.read_excel("시도별 전출입 인구수.xlsx",engine ='openpyxl', header =0 )

# %%
#누락값을 압 데이터로 체움 (엑셀 양식 벙합 부분)
df = df.fillna(method = 'ffill')

# %%
# 판다스에는 and 는 & 로 사용한다. 
#서울에서 다른지역으로 이동한 데이터만 추출하라 
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시') 

#마스크 적용 
df_seoul= df[mask]

#중간 데이터 , 이중에 서울특별시 지우고, 전입지별 ->전입지로 바꾸고, 인덱스로 만든다. 
print(df_seoul)
# Out:
#      전출지별     전입지별     1970     1971     1972     1973     1974     1975  \
# 19  서울특별시       전국  1448985  1419016  1210559  1647268  1819660  2937093
# 21  서울특별시    부산광역시    11568    11130    11768    16307    22220    27515
# 22  서울특별시    대구광역시        -        -        -        -        -        -
# 23  서울특별시    인천광역시        -        -        -        -        -        -
# 24  서울특별시    광주광역시        -        -        -        -        -        -
# 25  서울특별시    대전광역시        -        -        -        -        -        -
# 26  서울특별시    울산광역시        -        -        -        -        -        -
# 27  서울특별시  세종특별자치시        -        -        -        -        -        -
# 28  서울특별시      경기도   130149   150313    93333   143234   149045   253705
# 29  서울특별시      강원도     9352    12885    13561    16481    15479    27837
# 30  서울특별시     충청북도     6700     9457    10853    12617    11786    21073
# 31  서울특별시     충청남도    15954    18943    23406    27139    25509    51205
# ...

# %%
df_seoul = df_seoul.drop(['전출지별'],axis=1)

# %%
print(f"카운트 : maks.count: {mask.count()}")
# Out:
# 카운트 : maks.count: 325

# %%
print(f"카운트 : maks._value_counts(): {mask.value_counts()}")
# Out:
# 카운트 : maks._value_counts(): False    308
# True      17
# Name: count, dtype: int64

# %%
print(f"카운트 : df_seoul.count: {df_seoul.count}")
# Out:
# 카운트 : df_seoul.count: <bound method DataFrame.count of             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# ...

# %%
df_seoul
# Out:
#        전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
#전입지별 -> 전입지 
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)

# %%
df_seoul
# Out:
#         전입지     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
df_seoul.set_index('전입지', inplace=True)

# %%
df_seoul
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# 충청남도       15954    18943    23406    27139    25509    51205    41447
# ...

# %%
# 서울에서 경기도로 이동한 인구 데이터 값만 선택 
sr_one = df_seoul.loc['경기도']

# %%
sr_one
# Out:
# 1970    130149
# 1971    150313
# 1972     93333
# 1973    143234
# 1974    149045
# 1975    253705
# 1976    202276
# 1977    207722
# 1978    237684
# 1979    278411
# 1980    297539
# 1981    252073
# 1982    320174
# 1983    400875
# 1984    352238
# 1985    390265
# 1986    412535
# 1987    405220
# 1988    415174
# 1989    412933
# 1990    473889
# 1991    384714
# 1992    428344
# 1993    502584
# 1994    542204
# 1995    599411
# 1996    520566
# 1997    495454
# 1998    407050
# 1999    471841
# 2000    435573
# 2001    499575
# 2002    516765
# 2003    457656
# 2004    400206
# 2005    414621
# 2006    449632
# 2007    431637
# 2008    412408
# 2009    398282
# 2010    410735
# 2011    373771
# 2012    354135
# 2013    340801
# 2014    332785
# 2015    359337
# 2016    370760
# 2017    342433
# Name: 경기도, dtype: object

# %%
# x, y축 데이터를 plot 함수에 입력
plt.plot(sr_one.index, sr_one.values)

# %%
plt.plot(sr_one)
